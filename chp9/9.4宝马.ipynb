# %%
import requests
url ='https://c2b-services.bmw.com/c2b-localsearch/services/api/v3/clients/BMWDIGITAL_DLO/DE/pois?country=DE&category=BM&maxResults=%d&language=en&lat=52.507537768880056&lng=13.425269635701511'
jsonp = requests.get(url % 1000)
jsonp.content
# Out:
# D:\0ilraypan\python_work\env\hack\lib\site-packages\cryptography\hazmat\backends\openssl\x509.py:18: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   utils.DeprecatedIn35,
# b'callback({"status":{"key":null,"type":"OK","detail":null,"subsystem":null,"messages":null,"logKey":null},"translation":{},"metadata":{"serviceVersion":"3.0","lists":null,"colNames":[]},"data":{"pois":[{"key":"00081_3","name":"BMW AG Niederlassung Berlin Filiale Wei\xc3\x9fensee","countryCode":"DE","country":"Germany","state":null,"city":"Berlin","postalCode":"13088","postbox":null,"street":"Gehringstr. 20","lat":52.562568863415,"lng":13.463589476607,"dist":6.662869862853474,"oh":null,"attributes":{"distributionPartnerId":"00081","distributionCode":"NL","outletId":"3","homepage":"https://www.bmw-berlin.de/de/home/","phone":"+49 (30) 200990","fax":"+49 (30) 200992110","mail":"nl.berlin@bmw.de","facebookPlace":"","businessTypeCodes":["NO","PR"],"distributionBranches":["T","F","G"],"outletTypes":["FU"],"requestServices":["RFO","STL","TDA","RFI"],"services":["EB","PHEV"]},"category":"BMW"},{"key":"28147_1","name":"Autohaus Graubaum GmbH","countryCode":"DE","country":"Germany","state":null,"city":"Berlin","postalCode":"12439","postbox":null,"street":"K\xc3\xb6llnische Str. 10","lat":52.4528925,"lng":13.521265,"dist":8.921844225277006,"oh":null,"attributes":{"distributionPartnerId":"28147","distributionCode":"EH","outletId":"1","homepage":"http://www.graubaum-service.bmw","phone":"+49 (30) 6399030","fax":"+49 (30) 6317886","mail":"service@bmw-graubaum.de","facebookPlace":"","businessTypeCodes":["NO"],"distributionBranches":["T"],"outletTypes":["SE"],"requestServices":["RFA"],"services":[]},"category":"BMW"},{"key":"07825_2","name":"Autohaus Reier GmbH & Co. KG","countryCode":"DE","country":"Germany","state":null,"city":"Berlin","postalCode":"13405","postbox":null,"street":"Scharnweberstr. 132-133","lat":52.56473,"lng":13.32521,"dist":9.311068001726223,"oh":null,"attributes":{"distributionPartnerId":"07825","distributionCode":"EH","outletId":"2","homepage":"http://bmw-reier.de/de/home/","phone":"+49 (30) 4177910","fax":"+49 (30) 41779177","mail":"kontakt@autohaus-reier.de","facebookPlace":"","businessTypeCodes":["NO","PR"],"distributionBranches":["G","T"],"outletTypes":["SE"],"requestServices":["RFA"],"services":[]},"category":"BMW"},{"key":"00081_6","name":"BMW AG Niederlassung Berlin Filiale Marzahn","countryCode":"DE","country":"Germany","state":null,"city":"Berlin","postalCode":"12683","postbox":null,"street":"Blumberger Damm 2","lat":52.509789,"lng":13.563749,"dist":9.39990081267362,"oh":null,"attributes":{"distributionPartnerId":"00081","distributionCode":"NL","outletId":"6","homepage":"https://www.bmw-berlin.de/de/home/","phone":"+49 (30) 200990","fax":"+49 (30) 200993110","mail":"marzahn.nlb@bmw.de","facebookPlace":"","businessTypeCodes":["PR","NO"],"distributionBranches":["F","G","T"],"outletTypes":["FU"],"requestServices":["STL","RFO","RFI","TDA"],"services":["EB","PHEV"]},"category":"BMW"},{"key":"01872_1","name":"Riller & Schnauck GmbH","countryCode":"DE","country":"Germany","state":null,"city":"Berlin","postalCode":"12203","postbox":null,"street":"Hindenburgdamm 68","lat":52.4518,"lng":13.31541,"dist":9.70862896477466,"oh":null,"attributes":{"distributionPartnerId":"01872","distributionCode":"EH","outletId":"1","homepage":"http://www.bmw-riller-schnauck.de","phone":"+49 (30) 7900950","fax":"+49 (30) 790095400","mail":"anfrage@riller-schnauck.de","facebookPlace":"","businessTypeCodes":["MC","GA","NO","PR"],"distributionBranches":["F","G","T"],"outletTypes":["FU"],"requestServices":["RFA","STL","TDA","RFO","RFI"],"services":["EB","PHEV"]},"category":"BMW"},{"key":"00081_1","name":"BMW AG Niederlassung Berlin","countryCode":"DE","country":"Germany","state":null,"city":"Berlin","postalCode":"14057","postbox":null,"street":"Kaiserdamm 90/ Einfahrt Messedamm 1","lat":52.509665,"lng":13.282042,"dist":9.721651351525932,"oh":null,"attributes":{"distributionPartnerId":"00081","distributionCode":"NL","outletId":"1","homepage":"https://www.bmw-berlin.de/de/home/","phone":"+49 (30) 200990","fax":"+49 (30) 200991110","mail":"nl.berli ...

# %%
import json
pure_json = jsonp.text[jsonp.text.index('(') + 1 :
jsonp.text.rindex(')')]
dealers = json.loads(pure_json)
dealers.keys()
# Out:
# dict_keys(['status', 'translation', 'metadata', 'data', 'count'])

# %%
dealers['count']
# Out:
# 673

# %%
dealers['data']['pois'][0]
# Out:
# {'attributes': {'businessTypeCodes': ['NO', 'PR'],
#   'distributionBranches': ['T', 'F', 'G'],
#   'distributionCode': 'NL',
#   'distributionPartnerId': '00081',
#   'facebookPlace': '',
#   'fax': '+49 (30) 200992110',
#   'homepage': 'https://www.bmw-berlin.de/de/home/',
#   'mail': 'nl.berlin@bmw.de',
#   'outletId': '3',
#   'outletTypes': ['FU'],
#   'phone': '+49 (30) 200990',
#   'requestServices': ['RFO', 'STL', 'TDA', 'RFI'],
#   'services': ['EB', 'PHEV']},
#  'category': 'BMW',
#  'city': 'Berlin',
#  'country': 'Germany',
#  'countryCode': 'DE',
#  'dist': 6.662869862853474,
#  'key': '00081_3',
#  'lat': 52.562568863415,
#  'lng': 13.463589476607,
#  'name': 'BMW AG Niederlassung Berlin Filiale Weißensee',
#  'oh': None,
#  'postalCode': '13088',
#  'postbox': None,
#  'state': None,
#  'street': 'Gehringstr. 20'}

# %%
# %run bmw_scraper.py
# Out:
# D:\0ilraypan\python_work\env\hack\lib\site-packages\cryptography\hazmat\backends\openssl\x509.py:18: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   utils.DeprecatedIn35,
# dict_keys(['status', 'translation', 'metadata', 'data', 'count'])
# 673
# {'key': '00081_3', 'name': 'BMW AG Niederlassung Berlin Filiale Weißensee', 'countryCode': 'DE', 'country': 'Germany', 'state': None, 'city': 'Berlin', 'postalCode': '13088', 'postbox': None, 'street': 'Gehringstr. 20', 'lat': 52.562568863415, 'lng': 13.463589476607, 'dist': 6.662869862853474, 'oh': None, 'attributes': {'distributionPartnerId': '00081', 'distributionCode': 'NL', 'outletId': '3', 'homepage': 'https://www.bmw-berlin.de/de/home/', 'phone': '+49 (30) 200990', 'fax': '+49 (30) 200992110', 'mail': 'nl.berlin@bmw.de', 'facebookPlace': '', 'businessTypeCodes': ['NO', 'PR'], 'distributionBranches': ['T', 'F', 'G'], 'outletTypes': ['FU'], 'requestServices': ['RFO', 'STL', 'TDA', 'RFI'], 'services': ['EB', 'PHEV']}, 'category': 'BMW'}
