# %% [raw]
# redis-cli
# FLUSHALL

# %%
# %run threaded_crawler.py
# Out:
# 5
# [<Thread(Thread-8, started daemon 16520)>, <Thread(Thread-9, started daemon 11900)>, <Thread(Thread-10, started daemon 13780)>, <Thread(Thread-11, started daemon 19688)>, <Thread(Thread-12, started daemon 21192)>]
# Blocked by robots.txt: http://google.be
# Blocked by robots.txt: http://ojooo.com
# Downloading: http://people.com.cn
# Downloading: http://heavy.com
# Loaded from cache: http://schwab.com
# Downloading: http://cnbcindonesia.com
# Loaded from cache: http://cnbcindonesia.com
# Loaded from cache: http://uptodown.com
# Loaded from cache: http://chaduo.com
# Loaded from cache: http://pcbaby.com.cn
# Loaded from cache: http://pcbaby.com.cn
# Loaded from cache: http://oberlo.com
# Loaded from cache: http://freshdesk.com
# Loaded from cache: http://rambler.ru
# Blocked by robots.txt: http://gate.io
# Loaded from cache: http://shopee.co.th
# Loaded from cache: http://breitbart.com
# Loaded from cache: http://shopee.vn
# Loaded from cache: http://olx.ua
# ...
