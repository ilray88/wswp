# %%
# %run advanced_link_crawler.py
# Out:
# Loaded from cache: http://people.com.cn
# Error finding robots_url: http://louisvuitton.com/robots.txt timed out
# Downloading: http://louisvuitton.com
# Download error: HTTPConnectionPool(host='louisvuitton.com', port=80): Read timed out. (read timeout=60)
# Downloading: http://cnbcindonesia.com
# Loaded from cache: http://cnbcindonesia.com
# Downloading: http://heavy.com
# Blocked by robots.txt: http://google.be
# Blocked by robots.txt: http://ojooo.com
# Downloading: http://schwab.com
# Downloading: http://oberlo.com
# Downloading: http://uptodown.com
# Downloading: http://rambler.ru
# Downloading: http://pcbaby.com.cn
# Loaded from cache: http://pcbaby.com.cn
# Downloading: http://chaduo.com
# Download error:
# <html>
# <head>
# <title>ERROR</title>
# </head>
# <body>
# <center><h2>温馨提示：<span class="red">该网站因未备案或接入非法内容暂时无法进行访问，请联系接入商。</span></h2></center>
#
#
#
#
#
#
#
#
# </body>
# </html>
#
# Downloading: http://jw.org
# Downloading: http://freshdesk.com
# ...
