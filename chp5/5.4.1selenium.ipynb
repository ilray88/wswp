# %%
# !pip install selenium
# Out:
# ^C

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in d:\0ilraypan\python_work\env\hack\lib\site-packages (21.3.1)

# %%
from selenium import webdriver
driver = webdriver.Chrome()
# Out:
# Exception ignored in: <bound method Service.__del__ of <selenium.webdriver.chrome.service.Service object at 0x00000150A1213828>>
# Traceback (most recent call last):
#   File "D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\common\service.py", line 176, in __del__
#     self.stop()
#   File "D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\common\service.py", line 151, in stop
#     self.send_remote_shutdown_command()
#   File "D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\common\service.py", line 132, in send_remote_shutdown_command
#     if not self.is_connectable():
#   File "D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\common\service.py", line 115, in is_connectable
#     return utils.is_connectable(self.port)
#   File "D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\common\utils.py", line 106, in is_connectable
#     socket_ = socket.create_connection((host, port), 1)
#   File "D:\0ilraypan\python_work\env\hack\lib\socket.py", line 713, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt:

# %%
driver.get('http://example.python-scraping.com/search')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-65-0ca60a56a2a6> in <module>()
# ----> 1 driver.get('http://example.python-scraping.com/search')
#       2
#
# D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# D:\0ilraypan\python_work\env\hack\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=95.0.4638.17)

# %%
driver.find_element_by_id('search_term').send_keys('.')

# %%
js = "document.getElementById('page_size').options[1].text = '1000';"
driver.execute_script(js)

# %%
driver.find_element_by_id('search').click()

# %%
driver.implicitly_wait(30)

# %%
links = driver.find_elements_by_css_selector('#results a')

# %%
countries_or_districts = [link.text for link in links]
print(countries_or_districts)

# %%
driver.close()

# %% [markdown]
# ## 1．Selenium与无界面浏览器

# %%
from selenium import webdriver
options=webdriver.ChromeOptions()
options.set_headless()
# options.add_argument('--headless')
options.add_argument('--disable-gpu')
driver=webdriver.Chrome(options=options)
driver.get('http://python.org')
driver.save_screenshot('../data/python_website.png')
driver.close()

# %%
from IPython.display import Image
Image(filename = '../data/python_website.png', width=100, height=60)

# %%
# Out:
# '[]' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。
